# %% [markdown]
# # Mountain Car Task using Normalized Radial Basis functions.
#
# This is example 10.1 from Sutton/Barto, with a different state space representation.

# %%
from mountain_car import MountainCar
import altair as alt
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## Initialize MountainCar and run N-Step Semi-gradient Sarsa

# %%
num_episodes = 500
mountain_car = MountainCar(alpha=.3, distance_scaler=.005, n=4, seed=1)
results = mountain_car.run(num_episodes=num_episodes)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [01:42<00:00,  4.90it/s]

# %% [markdown]
# # Plot the position of the car over time on the first vs last episode

# %%
mountain_car.plot_episode_pos_over_time(0) | mountain_car.plot_episode_pos_over_time(num_episodes - 1)
# Out:
# C:\Users\Duane\Envs\youtube\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.HConcatChart(...)

# %% [markdown]
# ## Plot Final Estimated Time Left and the last episode state-space path through it.
#
# Estimated Time Left is the same as "cost to go" in the book.

# %%
mountain_car.plot_est_time_left(episode_trail_plot=-1)
# Out:
# C:\Users\Duane\Envs\youtube\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.LayerChart(...)

# %% [markdown]
# ## Plot number of steps needed per episode

# %%
mountain_car.plot_steps_per_episode()
# Out:
# C:\Users\Duane\Envs\youtube\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)
